# %% [markdown]
# # Data Science Salaries Analysis (Pandas & NumPy Exercise)
#
# **Author:** Keshav Sriram Kumar
# **Objective:** Perform data analysis on the Data Science Salaries dataset using Pandas and NumPy, filtering geographic sub-groups, calculating summary statistics, and retrieving target records.# Week 2 - Exercise
# ### Notebook created by Keshav Sriram Kumar

# %% [markdown]
# In this exercise you are going to download and examine a csv file.  Produce output for the statements below.  You are required to look up some of the dataframe commands to get the answers as not all commands were covered in the lecture.

# %% [markdown]
# Start by importing the appropriate libraries and downloading the dataset from: <br>
# https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023
# <br>
# Read the file into a dataframe

# %%
import numpy as np
import pandas as pd

# %%
dsSalaryDF = pd.read_csv('ds_salaries.csv')

# %% [markdown]
# display the first 5 records of the dataframe

# %%
dsSalaryDF.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %% [markdown]
# Display the info of the dataframe

# %%
dsSalaryDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %% [markdown]
# What is the number of unique values under each category?

# %%
dsSalaryDF.nunique()
# Out:
# work_year                4
# experience_level         4
# employment_type          4
# job_title               93
# salary                 815
# salary_currency         20
# salary_in_usd         1035
# employee_residence      78
# remote_ratio             3
# company_location        72
# company_size             3
# dtype: int64

# %% [markdown]
# How many of these employees have residence in Canada?

# %%
dsSalaryDF['employee_residence'].value_counts()['CA']
# Out:
# np.int64(85)

# %% [markdown]
# Create a dataframe of just Canadian residence called CanDF

# %%
CanDF = dsSalaryDF[dsSalaryDF['employee_residence'] == 'CA']
CanDF
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 3          2023               SE              FT      Data Scientist  175000
# 4          2023               SE              FT      Data Scientist  120000
# 7          2023               SE              FT      Data Scientist  219000
# 8          2023               SE              FT      Data Scientist  141000
# 29         2023               SE              FT     Data Strategist   90000
# ...         ...              ...             ...                 ...     ...
# 3604       2021               SE              FT      Data Scientist  130000
# 3608       2021               MI              FT  Research Scientist   80000
# 3645       2021               SE              FT        Data Analyst   90000
# 3653       2021               SE              FT  Research Scientist  120500
# 3714       2021               SE              FT      Data Scientist  110000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3                USD         175000                 CA           100
# 4                USD         120000                 CA           100
# 7                USD         219000                 CA             0
# 8                USD         141000                 CA             0
# 29               USD          90000                 CA             0
# ...              ...            ...                ...           ...
# 3604             CAD         103691                 CA           100
# 3608             CAD          63810                 CA           100
# 3645             CAD          71786                 CA           100
# 3653             CAD          96113                 CA            50
# 3714             CAD          87738                 CA           100
#
#      company_location company_size
# 3                  CA            M
# 4                  CA            M
# 7                  CA            M
# 8                  CA            M
# 29                 CA            M
# ...               ...          ...
# 3604               CA            L
# 3608               CA            M
# 3645               CA            M
# 3653               CA            L
# 3714               CA            S
#
# [85 rows x 11 columns]

# %% [markdown]
# What is the min, max, and average salary for your CanDF?

# %%
CanDF.min()
# Out:
# work_year                                      2020
# experience_level                                 EN
# employment_type                                  FL
# job_title             3D Computer Vision Researcher
# salary                                        10000
# salary_currency                                 CAD
# salary_in_usd                                 10000
# employee_residence                               CA
# remote_ratio                                      0
# company_location                                 AL
# company_size                                      L
# dtype: object

# %%
CanDF.max()
# Out:
# work_year                           2023
# experience_level                      SE
# employment_type                       FT
# job_title             Research Scientist
# salary                            275000
# salary_currency                      USD
# salary_in_usd                     275000
# employee_residence                    CA
# remote_ratio                         100
# company_location                      US
# company_size                           S
# dtype: object

# %%
CanDF['salary'].mean()
# Out:
# np.float64(140282.35294117648)

# %% [markdown]
# Using iloc Display the record of the highest paid employee in CanDF

# %%
max_sal_index = CanDF['salary'].argmax()        #idxmax make a reference from the dsSalaryDF.
                                                #argmax get reference from the CanDF.
max_sal_index

# row_position = CanDF.index.get_loc(max_sal_index)
# row_position

CanDF.iloc[max_sal_index]
# Out:
# work_year                     2022
# experience_level                SE
# employment_type                 FT
# job_title             AI Developer
# salary                      275000
# salary_currency                USD
# salary_in_usd               275000
# employee_residence              CA
# remote_ratio                     0
# company_location                CA
# company_size                     S
# Name: 323, dtype: object
