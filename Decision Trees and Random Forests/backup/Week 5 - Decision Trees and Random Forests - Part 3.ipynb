# %% [markdown]
# # Week 5 - Decision Trees and Random Forests
# #### Part 3
# ### Notebook created by Jonathan Penava
# By the end of this lesson you should know what a decision tree algorithm is, how it is constructed, and how to create a machine learning algorithm that uses decision trees.

# %% [markdown]
# ## Overview
# - Data Mining vs Machine Learning
# - Decision Trees in Detail
# - <span style="color:red;">Decision Tree Example</span>
# - Random Forests

# %% [markdown]
# Let's run through some of the basic steps that we covered before

# %%
#DEcision tree is also now as white box algorithum


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

titanic = sns.load_dataset('titanic')

titanic.drop('embark_town', axis=1, inplace=True)
titanic.drop('embarked', axis=1, inplace=True)
titanic.drop('deck', axis=1, inplace=True)
titanic.drop('class', axis=1, inplace=True)
titanic.drop('alive', axis=1, inplace=True)

titanic.replace('male', 0, inplace=True)
titanic.replace('female', 1, inplace=True)
titanic.replace('man', 0, inplace=True)
titanic.replace('woman', 1, inplace=True)
titanic.replace('child', 2, inplace=True)

titanic.dropna(axis=0, inplace=True)

#Remove the dependent data (our y) from our independent data (our x values)
X, y = titanic.drop('survived', axis=1), titanic['survived'].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=87)
# Out:
# C:\Users\kesha\AppData\Local\Temp\ipykernel_4520\2648543462.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic.replace('female', 1, inplace=True)
# C:\Users\kesha\AppData\Local\Temp\ipykernel_4520\2648543462.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic.replace('child', 2, inplace=True)

# %% [markdown]
# Now that we have our training data, let's use the decision tree model as our algorithm.

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)


predictions = dtree.predict(X_test)

from sklearn.metrics import classification_report

#####
#Use the trained algorithm to make a prediction.
#####

print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79       130
#            1       0.67      0.78      0.72        85
#
#     accuracy                           0.76       215
#    macro avg       0.76      0.77      0.76       215
# weighted avg       0.77      0.76      0.76       215

# %% [markdown]
# Not quite as accurate as our logistic regression.  We saw this report in our previous class, let's go into a little more detail about what each of these columns are.
#
# We have 4 possibilities:
# <ul>
# <li>TN - True Negative</li>
# <li>TP - True Positive</li>
# <li>FN - False Negative</li>
# <li>FP - False Positive</li>
# </ul>
# <br>
# Presicion - Measures the accuracy of our positive predictions. <br>
# Precision = TP / (TP + FP)<br>
# <br>
# Recall - The percentage of positive cases that were correctly identified.<br>
# Recall = TP / (TP + FN) <br>
# <br>
# F1 Socre - The percent of positive predictions that were correct.<br>
# F1 Socre = 2*(Recall * Precision) / (Recall + Precision) <br>

# %% [markdown]
# We can also see the tree diagram that our model created.

# %% [markdown]
# Extra

# %%
dtree.score(X_test, y_test)
# Out:
# 0.7627906976744186

# %% [markdown]
# Extra

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, dtree.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79       130
#            1       0.67      0.78      0.72        85
#
#     accuracy                           0.76       215
#    macro avg       0.76      0.77      0.76       215
# weighted avg       0.77      0.76      0.76       215

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  who  adult_male  alone
# 0         0       3    0  22.0      1      0   7.2500    0        True  False
# 1         1       1    1  38.0      1      0  71.2833    1       False  False
# 2         1       3    1  26.0      0      0   7.9250    1       False   True
# 3         1       1    1  35.0      1      0  53.1000    1       False  False
# 4         0       3    0  35.0      0      0   8.0500    0        True   True

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80, 40))  # Set the figure size
fn = ['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'who', 'adult_male', 'alone']
cn = ['Died', 'Survived']
plot_tree(dtree, filled=True, feature_names=fn, class_names=cn)
# Out:
# [Text(0.5443674945414847, 0.96875, 'who <= 0.5\ngini = 0.484\nsamples = 499\nvalue = [294, 205]\nclass = Died'),
#  Text(0.3005253820960699, 0.90625, 'pclass <= 1.5\ngini = 0.312\nsamples = 290\nvalue = [234.0, 56.0]\nclass = Died'),
#  Text(0.42244643831877726, 0.9375, 'True  '),
#  Text(0.08733624454148471, 0.84375, 'age <= 36.5\ngini = 0.482\nsamples = 74\nvalue = [44, 30]\nclass = Died'),
#  Text(0.043668122270742356, 0.78125, 'fare <= 37.812\ngini = 0.477\nsamples = 28\nvalue = [11, 17]\nclass = Survived'),
#  Text(0.017467248908296942, 0.71875, 'fare <= 27.15\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Survived'),
#  Text(0.008733624454148471, 0.65625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Survived'),
#  Text(0.026200873362445413, 0.65625, 'fare <= 28.875\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.017467248908296942, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.034934497816593885, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.06986899563318777, 0.71875, 'fare <= 387.665\ngini = 0.484\nsamples = 17\nvalue = [10, 7]\nclass = Died'),
#  Text(0.0611353711790393, 0.65625, 'fare <= 123.258\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = Died'),
#  Text(0.05240174672489083, 0.59375, 'fare <= 52.55\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.043668122270742356, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.0611353711790393, 0.53125, 'age <= 33.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Survived'),
#  Text(0.05240174672489083, 0.46875, 'age <= 22.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Survived'),
#  Text(0.043668122270742356, 0.40625, 'age <= 18.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.034934497816593885, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.05240174672489083, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.0611353711790393, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.06986899563318777, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.06986899563318777, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.07860262008733625, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.13100436681222707, 0.78125, 'sibsp <= 0.5\ngini = 0.405\nsamples = 46\nvalue = [33.0, 13.0]\nclass = Died'),
#  Text(0.11353711790393013, 0.71875, 'fare <= 31.66\ngini = 0.32\nsamples = 30\nvalue = [24, 6]\nclass = Died'),
#  Text(0.10480349344978165, 0.65625, 'fare <= 30.75\ngini = 0.457\nsamples = 17\nvalue = [11, 6]\nclass = Died'),
#  Text(0.09606986899563319, 0.59375, 'age <= 41.0\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Died'),
#  Text(0.08733624454148471, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.10480349344978165, 0.53125, 'age <= 53.0\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = Died'),
#  Text(0.08733624454148471, 0.46875, 'fare <= 27.525\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Survived'),
#  Text(0.07860262008733625, 0.40625, 'age <= 46.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.06986899563318777, 0.34375, 'fare <= 26.419\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.0611353711790393, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.07860262008733625, 0.28125, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.08733624454148471, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.09606986899563319, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.1222707423580786, 0.46875, 'age <= 72.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.11353711790393013, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.13100436681222707, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.11353711790393013, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.1222707423580786, 0.65625, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Died'),
#  Text(0.14847161572052403, 0.71875, 'fare <= 52.277\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = Died'),
#  Text(0.13973799126637554, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.1572052401746725, 0.65625, 'fare <= 52.827\ngini = 0.498\nsamples = 15\nvalue = [8, 7]\nclass = Died'),
#  Text(0.14847161572052403, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.16593886462882096, 0.59375, 'fare <= 56.415\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = Died'),
#  Text(0.1572052401746725, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.17467248908296942, 0.53125, 'age <= 41.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.16593886462882096, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.18340611353711792, 0.46875, 'age <= 47.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Died'),
#  Text(0.17467248908296942, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.19213973799126638, 0.40625, 'fare <= 97.765\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.18340611353711792, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.20087336244541484, 0.34375, 'sibsp <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.19213973799126638, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.2096069868995633, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5137145196506551, 0.84375, 'fare <= 48.092\ngini = 0.212\nsamples = 216\nvalue = [190, 26]\nclass = Died'),
#  Text(0.3986080786026201, 0.78125, 'age <= 32.25\ngini = 0.196\nsamples = 209\nvalue = [186, 23]\nclass = Died'),
#  Text(0.2513646288209607, 0.71875, 'fare <= 7.01\ngini = 0.248\nsamples = 131\nvalue = [112, 19]\nclass = Died'),
#  Text(0.19213973799126638, 0.65625, 'age <= 22.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.18340611353711792, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.20087336244541484, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.310589519650655, 0.65625, 'pclass <= 2.5\ngini = 0.232\nsamples = 127\nvalue = [110, 17]\nclass = Died'),
#  Text(0.2183406113537118, 0.59375, 'age <= 30.5\ngini = 0.064\nsamples = 30\nvalue = [29, 1]\nclass = Died'),
#  Text(0.2096069868995633, 0.53125, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Died'),
#  Text(0.22707423580786026, 0.53125, 'fare <= 11.75\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.2183406113537118, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.23580786026200873, 0.46875, 'fare <= 19.625\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.22707423580786026, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.2445414847161572, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.4028384279475983, 0.59375, 'age <= 28.75\ngini = 0.275\nsamples = 97\nvalue = [81, 16]\nclass = Died'),
#  Text(0.34279475982532753, 0.53125, 'fare <= 7.825\ngini = 0.235\nsamples = 81\nvalue = [70, 11]\nclass = Died'),
#  Text(0.28820960698689957, 0.46875, 'fare <= 7.785\ngini = 0.328\nsamples = 29\nvalue = [23, 6]\nclass = Died'),
#  Text(0.26200873362445415, 0.40625, 'fare <= 7.24\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = Died'),
#  Text(0.23580786026200873, 0.34375, 'fare <= 7.133\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = Died'),
#  Text(0.22707423580786026, 0.28125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.2445414847161572, 0.28125, 'fare <= 7.227\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Died'),
#  Text(0.23580786026200873, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.25327510917030566, 0.21875, 'age <= 21.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.2445414847161572, 0.15625, 'alone <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.23580786026200873, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.25327510917030566, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.26200873362445415, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.28820960698689957, 0.34375, 'alone <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Died'),
#  Text(0.2794759825327511, 0.28125, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.27074235807860264, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.28820960698689957, 0.21875, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.29694323144104806, 0.28125, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Died'),
#  Text(0.314410480349345, 0.40625, 'age <= 19.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.3056768558951965, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.3231441048034934, 0.34375, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.314410480349345, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.3318777292576419, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.39737991266375544, 0.46875, 'age <= 20.5\ngini = 0.174\nsamples = 52\nvalue = [47, 5]\nclass = Died'),
#  Text(0.37554585152838427, 0.40625, 'fare <= 8.104\ngini = 0.278\nsamples = 24\nvalue = [20, 4]\nclass = Died'),
#  Text(0.35807860262008734, 0.34375, 'fare <= 7.91\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Died'),
#  Text(0.34934497816593885, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.36681222707423583, 0.28125, 'sibsp <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Died'),
#  Text(0.35807860262008734, 0.21875, 'age <= 19.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.34934497816593885, 0.15625, 'age <= 17.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.3406113537117904, 0.09375, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.35807860262008734, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.36681222707423583, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.37554585152838427, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3930131004366812, 0.34375, 'age <= 19.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Died'),
#  Text(0.38427947598253276, 0.28125, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Died'),
#  Text(0.4017467248908297, 0.28125, 'parch <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.3930131004366812, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.4104803493449782, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4192139737991266, 0.40625, 'fare <= 17.444\ngini = 0.069\nsamples = 28\nvalue = [27, 1]\nclass = Died'),
#  Text(0.4104803493449782, 0.34375, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Died'),
#  Text(0.4279475982532751, 0.34375, 'fare <= 19.681\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.4192139737991266, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4366812227074236, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.462882096069869, 0.53125, 'fare <= 7.835\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Died'),
#  Text(0.45414847161572053, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.47161572052401746, 0.46875, 'age <= 31.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.45414847161572053, 0.40625, 'fare <= 7.988\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.44541484716157204, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.462882096069869, 0.34375, 'fare <= 8.775\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.45414847161572053, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.47161572052401746, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4890829694323144, 0.40625, 'fare <= 7.988\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.48034934497816595, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.4978165938864629, 0.34375, 'alone <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.4890829694323144, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5065502183406113, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5458515283842795, 0.71875, 'age <= 43.5\ngini = 0.097\nsamples = 78\nvalue = [74, 4]\nclass = Died'),
#  Text(0.5240174672489083, 0.65625, 'age <= 34.5\ngini = 0.043\nsamples = 46\nvalue = [45, 1]\nclass = Died'),
#  Text(0.5152838427947598, 0.59375, 'pclass <= 2.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Died'),
#  Text(0.5065502183406113, 0.53125, 'age <= 33.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.4978165938864629, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.5152838427947598, 0.46875, 'fare <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.5065502183406113, 0.40625, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.5240174672489083, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5240174672489083, 0.53125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.5327510917030568, 0.59375, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]\nclass = Died'),
#  Text(0.5676855895196506, 0.65625, 'age <= 45.25\ngini = 0.17\nsamples = 32\nvalue = [29, 3]\nclass = Died'),
#  Text(0.5502183406113537, 0.59375, 'age <= 44.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Died'),
#  Text(0.5414847161572053, 0.53125, 'fare <= 7.988\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.5327510917030568, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5502183406113537, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.5589519650655022, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5851528384279476, 0.59375, 'age <= 61.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]\nclass = Died'),
#  Text(0.5764192139737991, 0.53125, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Died'),
#  Text(0.5938864628820961, 0.53125, 'age <= 63.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.5851528384279476, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6026200873362445, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.62882096069869, 0.78125, 'fare <= 64.998\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Died'),
#  Text(0.6200873362445415, 0.71875, 'age <= 30.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.611353711790393, 0.65625, 'age <= 27.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6026200873362445, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6200873362445415, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.62882096069869, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.6375545851528385, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.7882096069868996, 0.90625, 'pclass <= 2.5\ngini = 0.409\nsamples = 209\nvalue = [60, 149]\nclass = Survived'),
#  Text(0.6662885507641921, 0.9375, '  False'),
#  Text(0.6855895196506551, 0.84375, 'fare <= 28.856\ngini = 0.14\nsamples = 119\nvalue = [9, 110]\nclass = Survived'),
#  Text(0.6681222707423581, 0.78125, 'fare <= 28.231\ngini = 0.237\nsamples = 51\nvalue = [7.0, 44.0]\nclass = Survived'),
#  Text(0.6593886462882096, 0.71875, 'age <= 55.5\ngini = 0.211\nsamples = 50\nvalue = [6, 44]\nclass = Survived'),
#  Text(0.6506550218340611, 0.65625, 'age <= 23.5\ngini = 0.183\nsamples = 49\nvalue = [5, 44]\nclass = Survived'),
#  Text(0.6419213973799127, 0.59375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Survived'),
#  Text(0.6593886462882096, 0.59375, 'age <= 27.5\ngini = 0.239\nsamples = 36\nvalue = [5, 31]\nclass = Survived'),
#  Text(0.6375545851528385, 0.53125, 'fare <= 19.875\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = Survived'),
#  Text(0.6200873362445415, 0.46875, 'fare <= 13.429\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.611353711790393, 0.40625, 'age <= 25.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.6026200873362445, 0.34375, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6200873362445415, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.62882096069869, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.6550218340611353, 0.46875, 'age <= 25.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.6462882096069869, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.6637554585152838, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6812227074235808, 0.53125, 'age <= 36.5\ngini = 0.137\nsamples = 27\nvalue = [2, 25]\nclass = Survived'),
#  Text(0.6724890829694323, 0.46875, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Survived'),
#  Text(0.6899563318777293, 0.46875, 'age <= 39.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Survived'),
#  Text(0.6812227074235808, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6986899563318777, 0.40625, 'fare <= 25.965\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Survived'),
#  Text(0.6899563318777293, 0.34375, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Survived'),
#  Text(0.7074235807860262, 0.34375, 'age <= 43.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.6986899563318777, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7161572052401747, 0.28125, 'pclass <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7074235807860262, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7248908296943232, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6681222707423581, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6768558951965066, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7030567685589519, 0.78125, 'parch <= 1.5\ngini = 0.057\nsamples = 68\nvalue = [2, 66]\nclass = Survived'),
#  Text(0.6943231441048034, 0.71875, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]\nclass = Survived'),
#  Text(0.7117903930131004, 0.71875, 'fare <= 135.775\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Survived'),
#  Text(0.7030567685589519, 0.65625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.7205240174672489, 0.65625, 'fare <= 206.963\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.7117903930131004, 0.59375, 'age <= 1.46\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.7030567685589519, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7205240174672489, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7292576419213974, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8908296943231441, 0.84375, 'fare <= 20.8\ngini = 0.491\nsamples = 90\nvalue = [51, 39]\nclass = Died'),
#  Text(0.8253275109170306, 0.78125, 'age <= 17.5\ngini = 0.489\nsamples = 61\nvalue = [26, 35]\nclass = Survived'),
#  Text(0.7729257641921398, 0.71875, 'fare <= 13.935\ngini = 0.287\nsamples = 23\nvalue = [4, 19]\nclass = Survived'),
#  Text(0.7554585152838428, 0.65625, 'age <= 3.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = Survived'),
#  Text(0.7467248908296943, 0.59375, 'age <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.7379912663755459, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.7554585152838428, 0.53125, 'fare <= 11.375\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7467248908296943, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7641921397379913, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7641921397379913, 0.59375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.7903930131004366, 0.65625, 'age <= 7.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.7816593886462883, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.7991266375545851, 0.59375, 'age <= 14.75\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.7903930131004366, 0.53125, 'age <= 10.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.7816593886462883, 0.46875, 'sex <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7729257641921398, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7903930131004366, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7991266375545851, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.8078602620087336, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8777292576419214, 0.71875, 'fare <= 20.231\ngini = 0.488\nsamples = 38\nvalue = [22, 16]\nclass = Died'),
#  Text(0.868995633187773, 0.65625, 'fare <= 9.413\ngini = 0.475\nsamples = 36\nvalue = [22, 14]\nclass = Died'),
#  Text(0.834061135371179, 0.59375, 'fare <= 8.673\ngini = 0.498\nsamples = 15\nvalue = [7, 8]\nclass = Survived'),
#  Text(0.8253275109170306, 0.53125, 'age <= 28.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = Died'),
#  Text(0.8165938864628821, 0.46875, 'age <= 18.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = Survived'),
#  Text(0.8078602620087336, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.8253275109170306, 0.40625, 'fare <= 8.258\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Survived'),
#  Text(0.8165938864628821, 0.34375, 'age <= 23.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.8078602620087336, 0.28125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.8253275109170306, 0.28125, 'age <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8165938864628821, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.834061135371179, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.834061135371179, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.834061135371179, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.8427947598253275, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9039301310043668, 0.59375, 'parch <= 2.5\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = Died'),
#  Text(0.8951965065502183, 0.53125, 'sibsp <= 2.5\ngini = 0.375\nsamples = 20\nvalue = [15, 5]\nclass = Died'),
#  Text(0.8864628820960698, 0.46875, 'age <= 54.0\ngini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = Died'),
#  Text(0.8777292576419214, 0.40625, 'age <= 30.0\ngini = 0.278\nsamples = 18\nvalue = [15, 3]\nclass = Died'),
#  Text(0.868995633187773, 0.34375, 'parch <= 1.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = Died'),
#  Text(0.8602620087336245, 0.28125, 'fare <= 9.84\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = Died'),
#  Text(0.851528384279476, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.868995633187773, 0.21875, 'fare <= 10.179\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Died'),
#  Text(0.8602620087336245, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8777292576419214, 0.15625, 'age <= 23.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Died'),
#  Text(0.868995633187773, 0.09375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.8864628820960698, 0.09375, 'age <= 25.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.8777292576419214, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8951965065502183, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.8777292576419214, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8864628820960698, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Died'),
#  Text(0.8951965065502183, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9039301310043668, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9126637554585153, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8864628820960698, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9563318777292577, 0.78125, 'age <= 6.0\ngini = 0.238\nsamples = 29\nvalue = [25, 4]\nclass = Died'),
#  Text(0.9388646288209607, 0.71875, 'parch <= 1.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Died'),
#  Text(0.9301310043668122, 0.65625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.9475982532751092, 0.65625, 'fare <= 31.331\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.9388646288209607, 0.59375, 'fare <= 26.65\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.9301310043668122, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9475982532751092, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.9563318777292577, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9737991266375546, 0.71875, 'age <= 34.0\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Died'),
#  Text(0.9650655021834061, 0.65625, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Died'),
#  Text(0.982532751091703, 0.65625, 'age <= 38.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.9737991266375546, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9912663755458515, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died')]
